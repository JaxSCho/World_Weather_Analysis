# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time

sys.path.insert(0, "/Users/jackiecho/Desktop/Analysis_Projects/World_Weather_Analysis/")

from citipy import citipy
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Create an empty list to hold the weather data.
city_data = []

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_curr_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_curr_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | loa janan
# Processing Record 4 of Set 1 | westport
# Processing Record 5 of Set 1 | nanlong
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | camocim
# Processing Record 8 of Set 1 | calvinia
# Processing Record 9 of Set 1 | milkovo
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | carnarvon
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | berbera
# Processing Record 16 of Set 1 | kavieng
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | longkou
# Processing Record 19 of Set 1 | tuatapere
# Processing Record 20 of Set 1 | fairbanks
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | tabou
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | upington
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | kumano
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | victoria
# Processing Record 30 of Set 1 | kamina
# Processing Record 31 of Set 1 | tessalit
# Processing Record 32 of Set 1 | la ronge
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | cabo san lucas
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | bambous virieux
# Processing Record 38 of Set 1 | constitucion
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | balkanabat
# Processing Record 43 of Set 1 | oudtshoorn
# Processing Record 44 of Set 1 | nishihara
# Processing Record 45 of Set 1 | hofn
# Processing Record 46 of Set 1 | klaksvik
# Processing Record 47 of Set 1 | tacuarembo
# Processing Record 48 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | west bay
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | shelburne
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | lahaina
# Processing Record 7 of Set 2 | majene
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 2 | mabaruma
# Processing Record 11 of Set 2 | mozarlandia
# Processing Record 12 of Set 2 | madera
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | dutlwe
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | port hedland
# Processing Record 17 of Set 2 | katiola
# Processing Record 18 of Set 2 | svecha
# Processing Record 19 of Set 2 | tongchuan
# Processing Record 20 of Set 2 | sao filipe
# Processing Record 21 of Set 2 | lumut
# Processing Record 22 of Set 2 | pareora
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | peniche
# Processing Record 25 of Set 2 | yumen
# Processing Record 26 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | abu samrah
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | likhoy
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | upernavik
# Processing Record 34 of Set 2 | nemuro
# Processing Record 35 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | lagoa
# Processing Record 38 of Set 2 | provideniya
# Processing Record 39 of Set 2 | praia
# Processing Record 40 of Set 2 | kiunga
# Processing Record 41 of Set 2 | puerto carreno
# Processing Record 42 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 43 of Set 2 | airai
# Processing Record 44 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 2 | dingle
# Processing Record 46 of Set 2 | kloulklubed
# Processing Record 47 of Set 2 | ojinaga
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | denia
# Processing Record 50 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | kirakira
# Processing Record 2 of Set 3 | beringovskiy
# Processing Record 3 of Set 3 | tura
# Processing Record 4 of Set 3 | manggar
# Processing Record 5 of Set 3 | san pedro
# Processing Record 6 of Set 3 | kununurra
# Processing Record 7 of Set 3 | morehead
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | ozinki
# Processing Record 11 of Set 3 | vila franca do campo
# Processing Record 12 of Set 3 | pimentel
# Processing Record 13 of Set 3 | ketchikan
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | playas
# Processing Record 16 of Set 3 | srandakan
# Processing Record 17 of Set 3 | denpasar
# Processing Record 18 of Set 3 | ayagoz
# Processing Record 19 of Set 3 | jawhar
# Processing Record 20 of Set 3 | toulepleu
# City not found. Skipping...
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | sambava
# Processing Record 23 of Set 3 | la trinitaria
# Processing Record 24 of Set 3 | dasoguz
# Processing Record 25 of Set 3 | neiafu
# Processing Record 26 of Set 3 | bubaque
# Processing Record 27 of Set 3 | sinnamary
# Processing Record 28 of Set 3 | haines junction
# Processing Record 29 of Set 3 | valparaiso
# Processing Record 30 of Set 3 | sabang
# Processing Record 31 of Set 3 | norman wells
# Processing Record 32 of Set 3 | vila velha
# Processing Record 33 of Set 3 | youghal
# Processing Record 34 of Set 3 | solsvik
# City not found. Skipping...
# Processing Record 35 of Set 3 | taclobo
# Processing Record 36 of Set 3 | kunming
# Processing Record 37 of Set 3 | upata
# Processing Record 38 of Set 3 | atikokan
# Processing Record 39 of Set 3 | ixtapa
# Processing Record 40 of Set 3 | butaritari
# Processing Record 41 of Set 3 | ribeira grande
# Processing Record 42 of Set 3 | sabha
# Processing Record 43 of Set 3 | axim
# Processing Record 44 of Set 3 | kapaa
# Processing Record 45 of Set 3 | laguna
# Processing Record 46 of Set 3 | caravelas
# Processing Record 47 of Set 3 | tiksi
# Processing Record 48 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 3 | sungaipenuh
# Processing Record 1 of Set 4 | koshekhabl
# Processing Record 2 of Set 4 | san-pedro
# Processing Record 3 of Set 4 | honiara
# Processing Record 4 of Set 4 | charleston
# Processing Record 5 of Set 4 | pacific grove
# Processing Record 6 of Set 4 | vestmannaeyjar
# Processing Record 7 of Set 4 | buckingham
# Processing Record 8 of Set 4 | maningrida
# Processing Record 9 of Set 4 | te anau
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | sharan
# Processing Record 12 of Set 4 | port-gentil
# Processing Record 13 of Set 4 | arraial do cabo
# Processing Record 14 of Set 4 | tulun
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | ancud
# Processing Record 17 of Set 4 | palmer
# Processing Record 18 of Set 4 | kysyl-syr
# Processing Record 19 of Set 4 | chokurdakh
# Processing Record 20 of Set 4 | asfi
# Processing Record 21 of Set 4 | lompoc
# Processing Record 22 of Set 4 | chekhov
# Processing Record 23 of Set 4 | coquimbo
# Processing Record 24 of Set 4 | jacareacanga
# Processing Record 25 of Set 4 | usinsk
# Processing Record 26 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 27 of Set 4 | makakilo city
# Processing Record 28 of Set 4 | padang
# Processing Record 29 of Set 4 | mount isa
# Processing Record 30 of Set 4 | zyryanka
# Processing Record 31 of Set 4 | tignere
# Processing Record 32 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 4 | alcacer do sal
# Processing Record 34 of Set 4 | berdigestyakh
# Processing Record 35 of Set 4 | oranjemund
# Processing Record 36 of Set 4 | eloy
# Processing Record 37 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 38 of Set 4 | swan hill
# Processing Record 39 of Set 4 | huarmey
# Processing Record 40 of Set 4 | hede
# Processing Record 41 of Set 4 | puerto berrio
# Processing Record 42 of Set 4 | bengkulu
# Processing Record 43 of Set 4 | meulaboh
# Processing Record 44 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 4 | chapais
# Processing Record 46 of Set 4 | high level
# Processing Record 47 of Set 4 | sola
# Processing Record 48 of Set 4 | fare
# Processing Record 49 of Set 4 | baiyin
# Processing Record 50 of Set 4 | rayong
# Processing Record 1 of Set 5 | khatanga
# Processing Record 2 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 5 | ahuimanu
# Processing Record 4 of Set 5 | isangel
# Processing Record 5 of Set 5 | vila
# Processing Record 6 of Set 5 | tazovskiy
# Processing Record 7 of Set 5 | clyde river
# Processing Record 8 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 5 | saqqez
# Processing Record 10 of Set 5 | kot samaba
# Processing Record 11 of Set 5 | tungor
# Processing Record 12 of Set 5 | khasan
# Processing Record 13 of Set 5 | sorland
# Processing Record 14 of Set 5 | atar
# Processing Record 15 of Set 5 | mantua
# Processing Record 16 of Set 5 | aranos
# Processing Record 17 of Set 5 | havre-saint-pierre
# Processing Record 18 of Set 5 | hithadhoo
# Processing Record 19 of Set 5 | sao felix do xingu
# Processing Record 20 of Set 5 | tromso
# Processing Record 21 of Set 5 | royal palm beach
# Processing Record 22 of Set 5 | guerrero negro
# Processing Record 23 of Set 5 | mangan
# Processing Record 24 of Set 5 | edd
# Processing Record 25 of Set 5 | karratha
# Processing Record 26 of Set 5 | santo tomas
# Processing Record 27 of Set 5 | finnsnes
# Processing Record 28 of Set 5 | san cristobal
# Processing Record 29 of Set 5 | san policarpo
# Processing Record 30 of Set 5 | necochea
# Processing Record 31 of Set 5 | chuy
# Processing Record 32 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 5 | katsuura
# Processing Record 34 of Set 5 | burgeo
# Processing Record 35 of Set 5 | taree
# Processing Record 36 of Set 5 | anito
# Processing Record 37 of Set 5 | vitina
# Processing Record 38 of Set 5 | san patricio
# Processing Record 39 of Set 5 | tautira
# Processing Record 40 of Set 5 | horsham
# Processing Record 41 of Set 5 | san juan
# Processing Record 42 of Set 5 | acapulco
# Processing Record 43 of Set 5 | asau
# Processing Record 44 of Set 5 | peleduy
# Processing Record 45 of Set 5 | mana
# Processing Record 46 of Set 5 | sisimiut
# Processing Record 47 of Set 5 | floirac
# Processing Record 48 of Set 5 | druzhba
# Processing Record 49 of Set 5 | cidreira
# Processing Record 50 of Set 5 | hirara
# Processing Record 1 of Set 6 | dongsheng
# Processing Record 2 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 6 | flinders
# Processing Record 4 of Set 6 | olafsvik
# Processing Record 5 of Set 6 | olinda
# Processing Record 6 of Set 6 | magadan
# Processing Record 7 of Set 6 | vicuna
# Processing Record 8 of Set 6 | ballina
# Processing Record 9 of Set 6 | nantucket
# Processing Record 10 of Set 6 | iqaluit
# Processing Record 11 of Set 6 | coroico
# Processing Record 12 of Set 6 | yerofey pavlovich
# Processing Record 13 of Set 6 | wagar
# Processing Record 14 of Set 6 | puerto quijarro
# Processing Record 15 of Set 6 | saint-pierre
# Processing Record 16 of Set 6 | santiago del estero
# Processing Record 17 of Set 6 | kargasok
# Processing Record 18 of Set 6 | kahului
# Processing Record 19 of Set 6 | marawi
# Processing Record 20 of Set 6 | comodoro rivadavia
# Processing Record 21 of Set 6 | roald
# Processing Record 22 of Set 6 | cap-aux-meules
# Processing Record 23 of Set 6 | plettenberg bay
# Processing Record 24 of Set 6 | hambantota
# Processing Record 25 of Set 6 | hovd
# Processing Record 26 of Set 6 | leh
# Processing Record 27 of Set 6 | miri
# Processing Record 28 of Set 6 | juegang
# Processing Record 29 of Set 6 | castle rock
# Processing Record 30 of Set 6 | ban nahin
# Processing Record 31 of Set 6 | san jeronimo de tunan
# City not found. Skipping...
# Processing Record 32 of Set 6 | clarence town
# Processing Record 33 of Set 6 | faanui
# Processing Record 34 of Set 6 | teguise
# Processing Record 35 of Set 6 | nurota
# Processing Record 36 of Set 6 | antofagasta
# Processing Record 37 of Set 6 | henties bay
# Processing Record 38 of Set 6 | anadyr
# Processing Record 39 of Set 6 | avera
# Processing Record 40 of Set 6 | batemans bay
# Processing Record 41 of Set 6 | bathsheba
# Processing Record 42 of Set 6 | taltal
# Processing Record 43 of Set 6 | feijo
# Processing Record 44 of Set 6 | mogadishu
# Processing Record 45 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 6 | joao pinheiro
# Processing Record 47 of Set 6 | erdaojiang
# Processing Record 48 of Set 6 | tartagal
# Processing Record 49 of Set 6 | tasiilaq
# Processing Record 50 of Set 6 | dori
# Processing Record 1 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 7 | cherskiy
# Processing Record 3 of Set 7 | namatanai
# Processing Record 4 of Set 7 | ayan
# Processing Record 5 of Set 7 | jalu
# Processing Record 6 of Set 7 | juneau
# Processing Record 7 of Set 7 | qaqortoq
# Processing Record 8 of Set 7 | hibbing
# Processing Record 9 of Set 7 | taksimo
# Processing Record 10 of Set 7 | puerto escondido
# Processing Record 11 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 12 of Set 7 | constantine
# Processing Record 13 of Set 7 | rio grande
# Processing Record 14 of Set 7 | zhoucheng
# Processing Record 15 of Set 7 | belaya gora
# Processing Record 16 of Set 7 | wadi musa
# Processing Record 17 of Set 7 | lebu
# Processing Record 18 of Set 7 | saint-francois
# Processing Record 19 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 7 | albi
# Processing Record 21 of Set 7 | kalengwa
# Processing Record 22 of Set 7 | oussouye
# Processing Record 23 of Set 7 | luanda
# Processing Record 24 of Set 7 | torbay
# Processing Record 25 of Set 7 | abu dhabi
# Processing Record 26 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 7 | ambilobe
# Processing Record 28 of Set 7 | rawson
# Processing Record 29 of Set 7 | bambanglipuro
# Processing Record 30 of Set 7 | kaitangata
# Processing Record 31 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 32 of Set 7 | pacifica
# Processing Record 33 of Set 7 | hasaki
# Processing Record 34 of Set 7 | solnechnyy
# Processing Record 35 of Set 7 | doka
# Processing Record 36 of Set 7 | zhigansk
# Processing Record 37 of Set 7 | srivardhan
# Processing Record 38 of Set 7 | asyut
# Processing Record 39 of Set 7 | ati
# Processing Record 40 of Set 7 | marzuq
# Processing Record 41 of Set 7 | saldanha
# Processing Record 42 of Set 7 | pandan
# Processing Record 43 of Set 7 | rincon
# Processing Record 44 of Set 7 | geraldton
# Processing Record 45 of Set 7 | kerki
# City not found. Skipping...
# Processing Record 46 of Set 7 | omsukchan
# Processing Record 47 of Set 7 | hamilton
# Processing Record 48 of Set 7 | andenes
# Processing Record 49 of Set 7 | qandala
# Processing Record 50 of Set 7 | catuday
# Processing Record 1 of Set 8 | buchanan
# Processing Record 2 of Set 8 | svetlogorsk
# Processing Record 3 of Set 8 | ilo
# Processing Record 4 of Set 8 | simbahan
# Processing Record 5 of Set 8 | nanortalik
# Processing Record 6 of Set 8 | wiang sa
# Processing Record 7 of Set 8 | bonavista
# Processing Record 8 of Set 8 | havoysund
# Processing Record 9 of Set 8 | maumere
# Processing Record 10 of Set 8 | paignton
# Processing Record 11 of Set 8 | sistranda
# Processing Record 12 of Set 8 | gamba
# Processing Record 13 of Set 8 | pochutla
# Processing Record 14 of Set 8 | eregli
# Processing Record 15 of Set 8 | lowestoft
# Processing Record 16 of Set 8 | waterloo
# Processing Record 17 of Set 8 | kautokeino
# Processing Record 18 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 8 | tilichiki
# Processing Record 20 of Set 8 | yenagoa
# Processing Record 21 of Set 8 | lebanon
# Processing Record 22 of Set 8 | ilulissat
# Processing Record 23 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 24 of Set 8 | kamir
# Processing Record 25 of Set 8 | luderitz
# Processing Record 26 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 8 | coracao de jesus
# Processing Record 28 of Set 8 | tomatlan
# Processing Record 29 of Set 8 | chicontepec
# Processing Record 30 of Set 8 | puerto castilla
# Processing Record 31 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 8 | talnakh
# Processing Record 33 of Set 8 | adolfo lopez mateos
# Processing Record 34 of Set 8 | sapele
# Processing Record 35 of Set 8 | tongliao
# Processing Record 36 of Set 8 | shubarkuduk
# Processing Record 37 of Set 8 | sao joao da barra
# Processing Record 38 of Set 8 | quatre cocos
# Processing Record 39 of Set 8 | sabya
# Processing Record 40 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 41 of Set 8 | mercedes
# Processing Record 42 of Set 8 | dzhebariki-khaya
# Processing Record 43 of Set 8 | nizhniy tsasuchey
# Processing Record 44 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 45 of Set 8 | bracebridge
# Processing Record 46 of Set 8 | lerwick
# Processing Record 47 of Set 8 | fatehpur
# Processing Record 48 of Set 8 | northam
# Processing Record 49 of Set 8 | husavik
# Processing Record 50 of Set 8 | impfondo
# Processing Record 1 of Set 9 | port blair
# Processing Record 2 of Set 9 | suamico
# Processing Record 3 of Set 9 | launceston
# Processing Record 4 of Set 9 | chulman
# Processing Record 5 of Set 9 | jamkhandi
# Processing Record 6 of Set 9 | khandyga
# Processing Record 7 of Set 9 | terrace bay
# Processing Record 8 of Set 9 | recas
# Processing Record 9 of Set 9 | bemidji
# Processing Record 10 of Set 9 | kavaratti
# Processing Record 11 of Set 9 | pangnirtung
# Processing Record 12 of Set 9 | narsaq
# Processing Record 13 of Set 9 | port macquarie
# Processing Record 14 of Set 9 | leningradskiy
# Processing Record 15 of Set 9 | calama
# Processing Record 16 of Set 9 | marsh harbour
# Processing Record 17 of Set 9 | paveh
# Processing Record 18 of Set 9 | ouahigouya
# Processing Record 19 of Set 9 | portland
# Processing Record 20 of Set 9 | udachnyy
# Processing Record 21 of Set 9 | hirado
# Processing Record 22 of Set 9 | los llanos de aridane
# Processing Record 23 of Set 9 | severo-kurilsk
# Processing Record 24 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 9 | souillac
# Processing Record 26 of Set 9 | tuktoyaktuk
# Processing Record 27 of Set 9 | college
# Processing Record 28 of Set 9 | moose factory
# Processing Record 29 of Set 9 | port antonio
# Processing Record 30 of Set 9 | ulverstone
# Processing Record 31 of Set 9 | forestville
# Processing Record 32 of Set 9 | nikolsk
# Processing Record 33 of Set 9 | takab
# Processing Record 34 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 9 | rocha
# Processing Record 36 of Set 9 | puerto ayacucho
# Processing Record 37 of Set 9 | chateau-thierry
# Processing Record 38 of Set 9 | pakokku
# Processing Record 39 of Set 9 | bethel
# Processing Record 40 of Set 9 | tapes
# Processing Record 41 of Set 9 | gat
# Processing Record 42 of Set 9 | amahai
# Processing Record 43 of Set 9 | faya
# Processing Record 44 of Set 9 | nosy varika
# Processing Record 45 of Set 9 | margate
# Processing Record 46 of Set 9 | semnan
# Processing Record 47 of Set 9 | yulara
# Processing Record 48 of Set 9 | santa cruz
# Processing Record 49 of Set 9 | amethi
# Processing Record 50 of Set 9 | dalbandin
# Processing Record 1 of Set 10 | lorengau
# Processing Record 2 of Set 10 | grindavik
# Processing Record 3 of Set 10 | krasnoselkup
# Processing Record 4 of Set 10 | havelock
# Processing Record 5 of Set 10 | sokone
# Processing Record 6 of Set 10 | lucapa
# Processing Record 7 of Set 10 | mikhaylovka
# Processing Record 8 of Set 10 | sitka
# Processing Record 9 of Set 10 | chengde
# Processing Record 10 of Set 10 | khotyn
# Processing Record 11 of Set 10 | ryazan
# Processing Record 12 of Set 10 | naze
# Processing Record 13 of Set 10 | taseyevo
# Processing Record 14 of Set 10 | gazanjyk
# Processing Record 15 of Set 10 | riyadh
# Processing Record 16 of Set 10 | vardo
# Processing Record 17 of Set 10 | shar
# Processing Record 18 of Set 10 | vao
# Processing Record 19 of Set 10 | gazojak
# Processing Record 20 of Set 10 | jinan
# Processing Record 21 of Set 10 | virginia beach
# Processing Record 22 of Set 10 | prince rupert
# Processing Record 23 of Set 10 | yaan
# Processing Record 24 of Set 10 | breytovo
# Processing Record 25 of Set 10 | hokitika
# Processing Record 26 of Set 10 | nome
# Processing Record 27 of Set 10 | gimli
# Processing Record 28 of Set 10 | pisco
# Processing Record 29 of Set 10 | phrai bung
# City not found. Skipping...
# Processing Record 30 of Set 10 | trairi
# Processing Record 31 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 32 of Set 10 | lac du bonnet
# Processing Record 33 of Set 10 | richards bay
# Processing Record 34 of Set 10 | gannan
# Processing Record 35 of Set 10 | pinawa
# Processing Record 36 of Set 10 | huaiyin
# Processing Record 37 of Set 10 | atambua
# Processing Record 38 of Set 10 | slave lake
# Processing Record 39 of Set 10 | kangaatsiaq
# Processing Record 40 of Set 10 | gillette
# Processing Record 41 of Set 10 | bar harbor
# Processing Record 42 of Set 10 | waipawa
# Processing Record 43 of Set 10 | kholodnyy
# Processing Record 44 of Set 10 | bend
# Processing Record 45 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 46 of Set 10 | vagur
# Processing Record 47 of Set 10 | donauworth
# Processing Record 48 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 10 | kenora
# Processing Record 50 of Set 10 | andrelandia
# Processing Record 1 of Set 11 | adrar
# Processing Record 2 of Set 11 | pozo colorado
# Processing Record 3 of Set 11 | lakes entrance
# Processing Record 4 of Set 11 | korhogo
# Processing Record 5 of Set 11 | fortuna
# Processing Record 6 of Set 11 | trincomalee
# Processing Record 7 of Set 11 | moche
# Processing Record 8 of Set 11 | yining
# Processing Record 9 of Set 11 | katangli
# Processing Record 10 of Set 11 | kaeo
# Processing Record 11 of Set 11 | sao jose da coroa grande
# Processing Record 12 of Set 11 | japura
# Processing Record 13 of Set 11 | ler
# Processing Record 14 of Set 11 | cedar city
# Processing Record 15 of Set 11 | tres picos
# Processing Record 16 of Set 11 | itoman
# Processing Record 17 of Set 11 | saint george
# Processing Record 18 of Set 11 | lavrentiya
# Processing Record 19 of Set 11 | celestun
# Processing Record 20 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 11 | zhanaozen
# Processing Record 22 of Set 11 | bandarbeyla
# Processing Record 23 of Set 11 | rosetta
# Processing Record 24 of Set 11 | vanavara
# Processing Record 25 of Set 11 | salalah
# Processing Record 26 of Set 11 | boca do acre
# Processing Record 27 of Set 11 | chenghai
# Processing Record 28 of Set 11 | khonsa
# Processing Record 29 of Set 11 | basco
# Processing Record 30 of Set 11 | khash
# Processing Record 31 of Set 11 | hammerfest
# Processing Record 32 of Set 11 | klyuchi
# Processing Record 33 of Set 11 | sur
# Processing Record 34 of Set 11 | languyan
# Processing Record 35 of Set 11 | alofi
# Processing Record 36 of Set 11 | umm kaddadah
# Processing Record 37 of Set 11 | tuxtepec
# Processing Record 38 of Set 11 | port hardy
# Processing Record 39 of Set 11 | kruisfontein
# Processing Record 40 of Set 11 | cayenne
# Processing Record 41 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 42 of Set 11 | hervey bay
# Processing Record 43 of Set 11 | alekseyevsk
# Processing Record 44 of Set 11 | puri
# Processing Record 45 of Set 11 | kalmunai
# Processing Record 46 of Set 11 | sept-iles
# Processing Record 47 of Set 11 | bama
# Processing Record 48 of Set 11 | ostrovnoy
# Processing Record 49 of Set 11 | panzhihua
# Processing Record 50 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 1 of Set 12 | maputo
# Processing Record 2 of Set 12 | sira
# Processing Record 3 of Set 12 | san vicente
# Processing Record 4 of Set 12 | carballo
# Processing Record 5 of Set 12 | diego de almagro
# Processing Record 6 of Set 12 | mount gambier
# Processing Record 7 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 12 | baihar
# Processing Record 9 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 10 of Set 12 | saint anthony
# Processing Record 11 of Set 12 | hondo
# Processing Record 12 of Set 12 | krasnyy yar
# Processing Record 13 of Set 12 | aloleng
# Processing Record 14 of Set 12 | hualmay
# Processing Record 15 of Set 12 | teacapan
# Processing Record 16 of Set 12 | tingo maria
# Processing Record 17 of Set 12 | egvekinot
# Processing Record 18 of Set 12 | lazaro cardenas
# Processing Record 19 of Set 12 | shimoda
# Processing Record 20 of Set 12 | kutum
# Processing Record 21 of Set 12 | korla
# Processing Record 22 of Set 12 | pemangkat
# Processing Record 23 of Set 12 | okhotsk
# Processing Record 24 of Set 12 | gadung
# Processing Record 25 of Set 12 | glencoe
# Processing Record 26 of Set 12 | pangai
# Processing Record 27 of Set 12 | teknaf
# Processing Record 28 of Set 12 | pimenta bueno
# Processing Record 29 of Set 12 | brigg
# Processing Record 30 of Set 12 | kaka
# Processing Record 31 of Set 12 | krasnousolskiy
# City not found. Skipping...
# Processing Record 32 of Set 12 | tual
# Processing Record 33 of Set 12 | salinas
# Processing Record 34 of Set 12 | touros
# Processing Record 35 of Set 12 | coihaique
# Processing Record 36 of Set 12 | yichang
# Processing Record 37 of Set 12 | grande prairie
# Processing Record 38 of Set 12 | srednekolymsk
# Processing Record 39 of Set 12 | south venice
# Processing Record 40 of Set 12 | duki
# Processing Record 41 of Set 12 | jiwani
# Processing Record 42 of Set 12 | almaznyy
# Processing Record 43 of Set 12 | hue
# Processing Record 44 of Set 12 | tome
# Processing Record 45 of Set 12 | mega
# Processing Record 46 of Set 12 | nuevo progreso
# Processing Record 47 of Set 12 | codrington
# Processing Record 48 of Set 12 | canchungo
# Processing Record 49 of Set 12 | aguimes
# Processing Record 50 of Set 12 | el tigre
# Processing Record 1 of Set 13 | sagaing
# Processing Record 2 of Set 13 | sande
# Processing Record 3 of Set 13 | astoria
# Processing Record 4 of Set 13 | talcahuano
# Processing Record 5 of Set 13 | birin
# Processing Record 6 of Set 13 | pontalina
# Processing Record 7 of Set 13 | wanning
# Processing Record 8 of Set 13 | jumla
# Processing Record 9 of Set 13 | yerbogachen
# Processing Record 10 of Set 13 | kiama
# Processing Record 11 of Set 13 | kalamazoo
# Processing Record 12 of Set 13 | berlevag
# Processing Record 13 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 13 | porto-vecchio
# Processing Record 15 of Set 13 | erenhot
# Processing Record 16 of Set 13 | evensk
# Processing Record 17 of Set 13 | hami
# Processing Record 18 of Set 13 | namibe
# Processing Record 19 of Set 13 | lodingen
# Processing Record 20 of Set 13 | marfino
# Processing Record 21 of Set 13 | locri
# Processing Record 22 of Set 13 | mitsamiouli
# Processing Record 23 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 13 | pag
# Processing Record 25 of Set 13 | timra
# Processing Record 26 of Set 13 | valdivia
# Processing Record 27 of Set 13 | shumskiy
# Processing Record 28 of Set 13 | roebourne
# Processing Record 29 of Set 13 | bo phloi
# Processing Record 30 of Set 13 | mishan
# Processing Record 31 of Set 13 | innisfail
# Processing Record 32 of Set 13 | carnduff
# Processing Record 33 of Set 13 | harper
# Processing Record 34 of Set 13 | tiarei
# Processing Record 35 of Set 13 | ambon
# Processing Record 36 of Set 13 | douglas
# Processing Record 37 of Set 13 | naryan-mar
# Processing Record 38 of Set 13 | zhangjiakou
# Processing Record 39 of Set 13 | itamaraca
# Processing Record 40 of Set 13 | chara
# Processing Record 41 of Set 13 | ahipara
# Processing Record 42 of Set 13 | ludvika
# Processing Record 43 of Set 13 | rockport
# Processing Record 44 of Set 13 | phalombe
# Processing Record 45 of Set 13 | champerico
# Processing Record 46 of Set 13 | kijang
# Processing Record 47 of Set 13 | binga
# Processing Record 48 of Set 13 | jalingo
# Processing Record 49 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 13 | washougal
# Processing Record 1 of Set 14 | labuan
# Processing Record 2 of Set 14 | katherine
# Processing Record 3 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 4 of Set 14 | bata
# Processing Record 5 of Set 14 | yaya
# Processing Record 6 of Set 14 | pathein
# Processing Record 7 of Set 14 | vostok
# Processing Record 8 of Set 14 | turkistan
# Processing Record 9 of Set 14 | dukat
# Processing Record 10 of Set 14 | shingu
# Processing Record 11 of Set 14 | vilhena
# Processing Record 12 of Set 14 | newport
# Processing Record 13 of Set 14 | alakurtti
# Processing Record 14 of Set 14 | san isidro
# Processing Record 15 of Set 14 | xingcheng
# Processing Record 16 of Set 14 | bocaranga
# City not found. Skipping...
# Processing Record 17 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 18 of Set 14 | nassjo
# Processing Record 19 of Set 14 | cortez
# Processing Record 20 of Set 14 | belmonte
# Processing Record 21 of Set 14 | mitu
# Processing Record 22 of Set 14 | cockburn town
# Processing Record 23 of Set 14 | vavatenina
# Processing Record 24 of Set 14 | macas
# Processing Record 25 of Set 14 | port pirie
# Processing Record 26 of Set 14 | gonen
# Processing Record 27 of Set 14 | tekeli
# Processing Record 28 of Set 14 | canutama
# Processing Record 29 of Set 14 | bud
# Processing Record 30 of Set 14 | daru
# Processing Record 31 of Set 14 | tokur
# Processing Record 32 of Set 14 | shorewood
# Processing Record 33 of Set 14 | bacolod
# Processing Record 34 of Set 14 | sakakah
# Processing Record 35 of Set 14 | scarborough
# Processing Record 36 of Set 14 | quelimane
# Processing Record 37 of Set 14 | broken hill
# Processing Record 38 of Set 14 | kondopoga
# Processing Record 39 of Set 14 | nyaunglebin
# Processing Record 40 of Set 14 | tambun
# Processing Record 41 of Set 14 | solikamsk
# Processing Record 42 of Set 14 | vargem alta
# Processing Record 43 of Set 14 | atasu
# Processing Record 44 of Set 14 | camacha
# Processing Record 45 of Set 14 | dunedin
# Processing Record 46 of Set 14 | eureka
# Processing Record 47 of Set 14 | maki
# Processing Record 48 of Set 14 | chiang klang
# Processing Record 49 of Set 14 | muros
# Processing Record 50 of Set 14 | amancio
# City not found. Skipping...
# Processing Record 1 of Set 15 | gualaceo
# Processing Record 2 of Set 15 | quezon
# Processing Record 3 of Set 15 | moree
# Processing Record 4 of Set 15 | tamale
# Processing Record 5 of Set 15 | port lincoln
# Processing Record 6 of Set 15 | khanpur
# Processing Record 7 of Set 15 | corner brook
# Processing Record 8 of Set 15 | price
# Processing Record 9 of Set 15 | robertsport
# Processing Record 10 of Set 15 | tupik
# Processing Record 11 of Set 15 | gushikawa
# Processing Record 12 of Set 15 | stornoway
# Processing Record 13 of Set 15 | santa maria
# Processing Record 14 of Set 15 | viedma
# Processing Record 15 of Set 15 | dubai
# Processing Record 16 of Set 15 | jadu
# Processing Record 17 of Set 15 | vanimo
# Processing Record 18 of Set 15 | hauterive
# Processing Record 19 of Set 15 | maltahohe
# Processing Record 20 of Set 15 | mapiripan
# Processing Record 21 of Set 15 | chiredzi
# Processing Record 22 of Set 15 | reyes
# Processing Record 23 of Set 15 | bogande
# Processing Record 24 of Set 15 | imeni babushkina
# Processing Record 25 of Set 15 | tigre
# Processing Record 26 of Set 15 | zatoka
# Processing Record 27 of Set 15 | nichinan
# Processing Record 28 of Set 15 | alpena
# Processing Record 29 of Set 15 | jining
# Processing Record 30 of Set 15 | mukhanovo
# City not found. Skipping...
# Processing Record 31 of Set 15 | caceres
# Processing Record 32 of Set 15 | antalaha
# Processing Record 33 of Set 15 | toungoo
# City not found. Skipping...
# Processing Record 34 of Set 15 | komsomolskiy
# Processing Record 35 of Set 15 | orlik
# Processing Record 36 of Set 15 | acaponeta
# Processing Record 37 of Set 15 | alta floresta
# Processing Record 38 of Set 15 | la grande
# Processing Record 39 of Set 15 | fomboni
# Processing Record 40 of Set 15 | paita
# Processing Record 41 of Set 15 | nanchang
# Processing Record 42 of Set 15 | dawei
# Processing Record 43 of Set 15 | tahe
# Processing Record 44 of Set 15 | nelson
# Processing Record 45 of Set 15 | sao gabriel da cachoeira
# Processing Record 46 of Set 15 | pak phanang
# Processing Record 47 of Set 15 | wonthaggi
# Processing Record 48 of Set 15 | kyra
# Processing Record 49 of Set 15 | fairview
# Processing Record 50 of Set 15 | raudeberg
# Processing Record 1 of Set 16 | ngama
# Processing Record 2 of Set 16 | hanzhong
# Processing Record 3 of Set 16 | chapayeve
# Processing Record 4 of Set 16 | massakory
# Processing Record 5 of Set 16 | bowen
# Processing Record 6 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 16 | sharkan
# Processing Record 8 of Set 16 | bilma
# Processing Record 9 of Set 16 | lakatoro
# Processing Record 10 of Set 16 | fez
# Processing Record 11 of Set 16 | pakxan
# Processing Record 12 of Set 16 | letka
# Processing Record 13 of Set 16 | gore
# Processing Record 14 of Set 16 | najran
# Processing Record 15 of Set 16 | rafai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 708

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Punta Arenas      CL -53.1500  -70.9167     41.11        87          40
# 1     Nikolskoye      RU  59.7035   30.7861     30.70        96          35
# 2      Loa Janan      ID  -0.5830  117.0950     70.61        94          98
# 3       Westport      US  41.1415  -73.3579     44.91        92         100
# 4        Nanlong      CN  31.3533  106.0631     58.53        77         100
# 5    Yellowknife      CA  62.4560 -114.3525     20.41        68          75
# 6        Camocim      BR  -2.9022  -40.8411     79.05        88          86
# 7       Calvinia      ZA -31.4707   19.7760     59.16        63           0
# 8        Milkovo      RU  54.7167  158.6167     12.15        82          19
# 9  Mar Del Plata      AR -38.0023  -57.5575     75.22        62          40
#
#    Wind Speed          Current Description
# 0       23.02  light intensity shower rain
# 1        2.95             scattered clouds
# 2        1.61              overcast clouds
# 3        5.75              overcast clouds
# 4        4.72                moderate rain
# 5       17.27                broken clouds
# 6        9.48         heavy intensity rain
# 7        7.56                    clear sky
# 8        4.21                   few clouds
# 9       21.85             scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "/Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
